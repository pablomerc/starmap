# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Define the list of input file paths
input_files = [
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset5/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset5/synthetic_starry_data_part_1.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset5/synthetic_starry_data_part_2.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset2/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset6/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset6/synthetic_starry_data_part_1.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset6/synthetic_starry_data_part_2.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset7/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset7/synthetic_starry_data_part_1.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset7/synthetic_starry_data_part_2.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset8/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset8/synthetic_starry_data_part_1.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset9/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset9/synthetic_starry_data_part_1.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset9/synthetic_starry_data_part_2.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset10/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset10/synthetic_starry_data_part_1.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset10/synthetic_starry_data_part_2.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset11/synthetic_starry_data_part_0.npz",
    "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset11/synthetic_starry_data_part_1.npz",

]

# Define the output file path
output_file = "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset_combined/synthetic_starry_data_combined.npz"

# Initialize a dictionary to hold the combined data
combined_data = {}

for input_file in input_files:
    # Load the data from the current file
    data = np.load(input_file, allow_pickle=True)

    # Iterate over each key in the loaded data
    for key in data.files:
        if key not in combined_data:
            combined_data[key] = data[key]
            continue
        # Append the data to the corresponding key in the combined dictionary
        # print("key", key, "shape", data[key].shape)
        # print("combined_data[key] shape", combined_data[key].shape)
        combined_data[key]=np.concatenate((combined_data[key], data[key]), axis=0)

    # Close the current file
    data.close()

print("Total number of images in the combined dataset:", len(combined_data["image"]))
# Out:
# Total number of images in the combined dataset: 10000

# %%
# ... (your loading and combining code) ...

# Define the output file path
output_file = "/pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset_combined/synthetic_starry_data_combined.npz"

# Ensure the output directory exists (optional, but good practice)
import os
output_dir = os.path.dirname(output_file)
if not os.path.exists(output_dir):
    print(f"\nOutput directory {output_dir} does not exist. Creating it.")
    try:
        os.makedirs(output_dir)
    except OSError as e:
        print(f"Error creating output directory {output_dir}: {e}")
        print("Cannot save the combined data. Exiting.")
        # Handle the error appropriately, maybe exit
        exit()

print('Total number of examples in the combined dataset:', len(combined_data['image']))


print("\nSaving combined data to:")
print(f"  {output_file}")
try:
    # Save the combined data to a single .npz file
    np.savez(output_file, **combined_data)
    print("Data successfully combined and saved.")
except Exception as e:
    print(f"An error occurred while saving the combined data: {e}")
# Out:
# Total number of examples in the combined dataset: 10000
#
# Saving combined data to:
#   /pdo/users/pablomer/starmap/starmap4astron/synthetic_data_output/dataset_combined/synthetic_starry_data_combined.npz
# Data successfully combined and saved.
